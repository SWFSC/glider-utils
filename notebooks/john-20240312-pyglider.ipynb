# %%
import os
from subprocess import run
from pyglider import slocum
from pyglider import utils
import numpy as np
import pandas as pd
import xarray as xr
from esdgliderutils.profiles import get_profiles_esd

# %%
deployment = 'john-20240312'
mode = 'delayed'
bucket_name = 'amlr-gliders-deployments-dev'

deployments_path = f'/home/sam_woodman_noaa_gov/{bucket_name}'
glider_path = os.path.join(deployments_path, 'REFOCUS', '2024', deployment)

cacdir = os.path.join(deployments_path, 'cache')
binarydir = os.path.join(glider_path, 'data', 'binary', mode)
deploymentyaml = os.path.join(glider_path, 'config', 
                              f"{deployment}-{mode}.yml")

l1tsdir = os.path.join(glider_path, 'data', 'nc', 'L1-timeseries')

run(["fusermount", "-u", deployments_path])
run(["gcsfuse", "--implicit-dirs", bucket_name,  deployments_path])
# Out:
# {"timestamp":{"seconds":1726072839,"nanos":97543585},"severity":"INFO","message":"Start gcsfuse/2.4.0 (Go version go1.22.4) for app \"\" using mount point: /home/sam_woodman_noaa_gov/amlr-gliders-deployments-dev\n"}
# {"timestamp":{"seconds":1726072839,"nanos":97816713},"severity":"INFO","message":"GCSFuse mount command flags: {\"AppName\":\"\",\"Foreground\":false,\"ConfigFile\":\"\",\"MountOptions\":{},\"DirMode\":493,\"FileMode\":420,\"Uid\":-1,\"Gid\":-1,\"ImplicitDirs\":true,\"OnlyDir\":\"\",\"RenameDirLimit\":0,\"IgnoreInterrupts\":true,\"CustomEndpoint\":null,\"BillingProject\":\"\",\"KeyFile\":\"\",\"TokenUrl\":\"\",\"ReuseTokenFromUrl\":true,\"EgressBandwidthLimitBytesPerSecond\":-1,\"OpRateLimitHz\":-1,\"SequentialReadSizeMb\":200,\"AnonymousAccess\":false,\"MaxRetrySleep\":30000000000,\"MaxRetryAttempts\":0,\"StatCacheCapacity\":20460,\"StatCacheTTL\":60000000000,\"TypeCacheTTL\":60000000000,\"KernelListCacheTtlSeconds\":0,\"HttpClientTimeout\":0,\"RetryMultiplier\":2,\"TempDir\":\"\",\"ClientProtocol\":\"http1\",\"MaxConnsPerHost\":0,\"MaxIdleConnsPerHost\":100,\"EnableNonexistentTypeCache\":false,\"StackdriverExportInterval\":0,\"PrometheusPort\":0,\"OtelCollectorAddress\":\"\",\"LogFile\":\"\",\"LogFormat\":\"json\",\"ExperimentalEnableJsonRead\":false,\"DebugFuse\":false,\"DebugGCS\":false,\"DebugInvariants\":false,\"DebugMutex\":false,\"ExperimentalMetadataPrefetchOnMount\":\"disabled\"}"}
# {"timestamp":{"seconds":1726072839,"nanos":97914463},"severity":"INFO","message":"GCSFuse mount config flags: {\"CreateEmptyFile\":false,\"Severity\":\"INFO\",\"Format\":\"\",\"FilePath\":\"\",\"LogRotateConfig\":{\"MaxFileSizeMB\":512,\"BackupFileCount\":10,\"Compress\":true},\"MaxSizeMB\":-1,\"CacheFileForRangeRead\":false,\"EnableParallelDownloads\":false,\"ParallelDownloadsPerFile\":16,\"MaxParallelDownloads\":16,\"DownloadChunkSizeMB\":50,\"EnableCRC\":false,\"CacheDir\":\"\",\"TtlInSeconds\":-9223372036854775808,\"TypeCacheMaxSizeMB\":4,\"StatCacheMaxSizeMB\":-9223372036854775808,\"EnableEmptyManagedFolders\":false,\"GRPCConnPoolSize\":1,\"AnonymousAccess\":false,\"EnableHNS\":false,\"IgnoreInterrupts\":true,\"DisableParallelDirops\":false,\"KernelListCacheTtlSeconds\":0,\"MaxRetryAttempts\":0,\"PrometheusPort\":0}"}
# {"timestamp":{"seconds":1726072839,"nanos":186058953},"severity":"INFO","message":"File system has been successfully mounted."}
# CompletedProcess(args=['gcsfuse', '--implicit-dirs', 'amlr-gliders-deployments-dev', '/home/sam_woodman_noaa_gov/amlr-gliders-deployments-dev'], returncode=0)

# %%
l1ts_outname_sci = slocum.binary_to_timeseries(
    binarydir, cacdir, l1tsdir, deploymentyaml,
    search='*.[d|e]bd', fnamesuffix='-sci',
    # search='*.[D|E]BD', fnamesuffix='',
    time_base='sci_water_temp', profile_filt_time=100,
    profile_min_time=300, maxgap=300)

# %%
l1ts_outname_oxy = slocum.binary_to_timeseries(
    binarydir, cacdir, l1tsdir, deploymentyaml,
    search='*.[d|e]bd', fnamesuffix='-oxy',
    # search='*.[D|E]BD', fnamesuffix='',
    time_base='sci_oxy4_oxygen', profile_filt_time=100,
    profile_min_time=300, maxgap=300)

# %%
l1ts_outname_eng = slocum.binary_to_timeseries(
    binarydir, cacdir, l1tsdir, deploymentyaml,
    search='*.[d|e]bd', fnamesuffix='-eng',
    # search='*.[D|E]BD', fnamesuffix='',
    time_base='m_depth', profile_filt_time=100,
    profile_min_time=300, maxgap=300)

# %%
ts_sci = xr.open_dataset(os.path.join(l1tsdir, f"{deployment}-sci.nc"))
ts_sci
# Out:
# <xarray.Dataset> Size: 124MB
# Dimensions:                (time: 735778)
# Coordinates:
#   * time                   (time) datetime64[ns] 6MB 2024-03-12T19:39:02.7040...
# Data variables: (12/20)
#     latitude               (time) float64 6MB ...
#     longitude              (time) float64 6MB ...
#     m_depth                (time) float64 6MB ...
#     heading                (time) float64 6MB ...
#     pitch                  (time) float64 6MB ...
#     roll                   (time) float64 6MB ...
#     ...                     ...
#     salinity               (time) float64 6MB ...
#     potential_density      (time) float64 6MB ...
#     density                (time) float64 6MB ...
#     potential_temperature  (time) float64 6MB ...
#     profile_index          (time) float64 6MB ...
#     profile_direction      (time) float64 6MB ...
# Attributes: (12/30)
#     Conventions:               CF-1.8
#     cdm_data_type:             Trajectory
#     ctd:                       {'serial': '0000', 'long_name': 'Conductivity,...
#     date_created:              2024-09-11T16:42:54Z
#     date_issued:               2024-09-11T16:42:54Z
#     date_modified:
#     ...                        ...
#     time_coverage_end:         2024-04-02T20:07:58.012000000
#     time_coverage_start:       2024-03-12T19:39:02.704000000
#     title:                     john-20240312T1939
#     wmo_id:
#     deployment_start:          2024-03-12T19:39:0
#     deployment_end:            2024-03-12T19:39:0

# %%
ts_sci = xr.open_dataset(os.path.join(l1tsdir, f"{deployment}-sci.nc"))
ts_oxy = xr.open_dataset(os.path.join(l1tsdir, f"{deployment}-oxy.nc"))
ts_eng = xr.open_dataset(os.path.join(l1tsdir, f"{deployment}-eng.nc"))
ts_sci
# list(ts_sci.data_vars)
# Out:
# <xarray.Dataset> Size: 124MB
# Dimensions:                (time: 735778)
# Coordinates:
#   * time                   (time) datetime64[ns] 6MB 2024-03-12T19:39:02.7040...
# Data variables: (12/20)
#     latitude               (time) float64 6MB ...
#     longitude              (time) float64 6MB ...
#     m_depth                (time) float64 6MB ...
#     heading                (time) float64 6MB ...
#     pitch                  (time) float64 6MB ...
#     roll                   (time) float64 6MB ...
#     ...                     ...
#     salinity               (time) float64 6MB ...
#     potential_density      (time) float64 6MB ...
#     density                (time) float64 6MB ...
#     potential_temperature  (time) float64 6MB ...
#     profile_index          (time) float64 6MB ...
#     profile_direction      (time) float64 6MB ...
# Attributes: (12/30)
#     Conventions:               CF-1.8
#     cdm_data_type:             Trajectory
#     ctd:                       {'serial': '0000', 'long_name': 'Conductivity,...
#     date_created:              2024-08-21T01:35:25Z
#     date_issued:               2024-08-21T01:35:25Z
#     date_modified:
#     ...                        ...
#     time_coverage_end:         2024-04-02T20:07:58.012000000
#     time_coverage_start:       2024-03-12T19:39:02.704000000
#     title:                     john-20240312T1939
#     wmo_id:
#     deployment_start:          2024-03-12T19:39:0
#     deployment_end:            2024-03-12T19:39:0

# %%
ts_oxy
# Out:
# <xarray.Dataset> Size: 123MB
# Dimensions:                (time: 735029)
# Coordinates:
#   * time                   (time) datetime64[ns] 6MB 2024-03-12T19:39:02.7040...
# Data variables: (12/20)
#     latitude               (time) float64 6MB ...
#     longitude              (time) float64 6MB ...
#     m_depth                (time) float64 6MB ...
#     heading                (time) float64 6MB ...
#     pitch                  (time) float64 6MB ...
#     roll                   (time) float64 6MB ...
#     ...                     ...
#     salinity               (time) float64 6MB ...
#     potential_density      (time) float64 6MB ...
#     density                (time) float64 6MB ...
#     potential_temperature  (time) float64 6MB ...
#     profile_index          (time) float64 6MB ...
#     profile_direction      (time) float64 6MB ...
# Attributes: (12/30)
#     Conventions:               CF-1.8
#     cdm_data_type:             Trajectory
#     ctd:                       {'serial': '0000', 'long_name': 'Conductivity,...
#     date_created:              2024-08-21T01:35:50Z
#     date_issued:               2024-08-21T01:35:50Z
#     date_modified:
#     ...                        ...
#     time_coverage_end:         2024-04-02T20:07:58.012000000
#     time_coverage_start:       2024-03-12T19:39:02.704000000
#     title:                     john-20240312T1939
#     wmo_id:
#     deployment_start:          2024-03-12T19:39:0
#     deployment_end:            2024-03-12T19:39:0

# %%
ts_eng
# Out:
# <xarray.Dataset> Size: 70MB
# Dimensions:                (time: 418751)
# Coordinates:
#   * time                   (time) datetime64[ns] 3MB 2024-03-12T19:39:06.9049...
# Data variables: (12/20)
#     latitude               (time) float64 3MB ...
#     longitude              (time) float64 3MB ...
#     m_depth                (time) float64 3MB ...
#     heading                (time) float64 3MB ...
#     pitch                  (time) float64 3MB ...
#     roll                   (time) float64 3MB ...
#     ...                     ...
#     salinity               (time) float64 3MB ...
#     potential_density      (time) float64 3MB ...
#     density                (time) float64 3MB ...
#     potential_temperature  (time) float64 3MB ...
#     profile_index          (time) float64 3MB ...
#     profile_direction      (time) float64 3MB ...
# Attributes: (12/30)
#     Conventions:               CF-1.8
#     cdm_data_type:             Trajectory
#     ctd:                       {'serial': '0000', 'long_name': 'Conductivity,...
#     date_created:              2024-08-21T01:36:15Z
#     date_issued:               2024-08-21T01:36:15Z
#     date_modified:
#     ...                        ...
#     time_coverage_end:         2024-04-02T21:20:35.744000000
#     time_coverage_start:       2024-03-12T19:39:06.904999936
#     title:                     john-20240312T1939
#     wmo_id:
#     deployment_start:          2024-03-12T19:39:0
#     deployment_end:            2024-03-12T19:39:0

# %%
# ts_sci.close()
# ts_oxy.close()
# ts_eng.close()

# %% [markdown]
# ## Testing times
#
# Main purpose of this section is to confirm that xarray.merge is doing what we expect

# %%
t1 = ts_sci.time.to_numpy()
t2 = ts_oxy.time.to_numpy()
t3 = ts_eng.time.to_numpy()

df_union = np.union1d(np.union1d(t1, t2), t3)
print(len(df_union))
df_union
# Out:
# 1529328
# array(['2024-03-12T19:39:02.704000000', '2024-03-12T19:39:06.904999936',
#        '2024-03-12T19:39:22.776000000', ...,
#        '2024-04-02T21:20:27.739000064', '2024-04-02T21:20:31.740999936',
#        '2024-04-02T21:20:35.744000000'], dtype='datetime64[ns]')

# %% [markdown]
# ## Combining datasets

# %%
vars_all = ['latitude', 'longitude', 'waypoint_latitude', 'waypoint_longitude']
sci_vars = vars_all + ['conductivity', 'temperature', 'pressure',
            'depth', 'salinity', 'potential_density', 'density', 'potential_temperature',
            'profile_index', 'profile_direction']
oxy_vars = vars_all + ["oxygen_concentration"]
eng_vars = vars_all + ["m_depth", "heading", "pitch", "roll"]

# %%
ts_sci = ts_sci[sci_vars]
ts_oxy = ts_oxy[oxy_vars]
ts_eng = ts_eng[eng_vars]

# %%
ts = xr.merge([ts_sci, ts_oxy, ts_eng], compat = "no_conflicts", 
              join  = "outer", combine_attrs = "override")
ts
# Out:
# <xarray.Dataset> Size: 245MB
# Dimensions:                (time: 1529328)
# Coordinates:
#   * time                   (time) datetime64[ns] 12MB 2024-03-12T19:39:02.704...
# Data variables: (12/19)
#     latitude               (time) float64 12MB nan 32.87 32.94 ... nan nan nan
#     longitude              (time) float64 12MB nan -117.3 -117.3 ... nan nan nan
#     waypoint_latitude      (time) float64 12MB nan 0.0 0.0 ... 32.76 32.76 32.76
#     waypoint_longitude     (time) float64 12MB nan 0.0 0.0 ... -119.3 -119.3
#     conductivity           (time) float64 12MB nan nan -0.00022 ... nan nan nan
#     temperature            (time) float64 12MB nan nan 21.78 nan ... nan nan nan
#     ...                     ...
#     profile_direction      (time) float64 12MB nan nan -0.0 nan ... nan nan nan
#     oxygen_concentration   (time) float64 12MB nan nan 232.5 nan ... nan nan nan
#     m_depth                (time) float64 12MB nan 0.8989 nan ... 0.2747 0.1161
#     heading                (time) float64 12MB nan 3.257 nan ... nan nan nan
#     pitch                  (time) float64 12MB nan -0.05934 nan ... nan nan nan
#     roll                   (time) float64 12MB nan 0.01222 nan ... nan nan nan
# Attributes: (12/30)
#     Conventions:               CF-1.8
#     cdm_data_type:             Trajectory
#     ctd:                       {'serial': '0000', 'long_name': 'Conductivity,...
#     date_created:              2024-08-21T01:35:25Z
#     date_issued:               2024-08-21T01:35:25Z
#     date_modified:
#     ...                        ...
#     time_coverage_end:         2024-04-02T20:07:58.012000000
#     time_coverage_start:       2024-03-12T19:39:02.704000000
#     title:                     john-20240312T1939
#     wmo_id:
#     deployment_start:          2024-03-12T19:39:0
#     deployment_end:            2024-03-12T19:39:0

# %%
# any(np.isnan(ts.latitude.values))
# good = ~np.isnan(ts.latitude.values + ts.longitude.values)

# print(np.nanmax(ts.latitude.values))
# print(np.max(ts.latitude.values[good]))

# %% [markdown]
# Recalculate attributes as necessary

# %%
good = ~np.isnan(ts.latitude.values + ts.longitude.values)
ts.attrs['geospatial_lat_max'] = np.nanmax(ts.latitude.values[good])
ts.attrs['geospatial_lat_min'] = np.nanmin(ts.latitude.values[good])
ts.attrs['geospatial_lon_max'] = np.nanmax(ts.longitude.values[good])
ts.attrs['geospatial_lon_min'] = np.nanmin(ts.longitude.values[good])
ts.attrs['geospatial_lat_units'] = 'degrees_north'
ts.attrs['geospatial_lon_units'] = 'degrees_east'

dt = ts.time.values
ts.attrs['time_coverage_start'] = '%s' % dt[0]
ts.attrs['time_coverage_end'] = '%s' % dt[-1]

ts.attrs['deployment_start'] = str(dt[0].astype('datetime64[s]'))
ts.attrs['deployment_end'] = str(dt[-1].astype('datetime64[s]'))

# %% [markdown]
# Recalculate profile values as necessary

# %%
depth_good = np.where(~np.isnan(ts.m_depth))[0]
ts.m_depth.values = np.interp(np.arange(len(ts.m_depth)), good, ts.m_depth.values[good])
ts = get_profiles_esd(ts, "m_depth")

# tg_ind = utils.find_gaps(ts.time.values[depth_good], ts.time.values, 300)
# np.where(tg_ind)
# dep = ts.m_depth.to_pandas()

ts = utils.get_distance_over_ground(ts)
ts

# %%
outname = os.path.join(l1tsdir, f"{deployment}-union.nc")
ts.to_netcdf(outname, 'w',
             encoding={'time': {'units': 'seconds since 1970-01-01T00:00:00Z',
                                '_FillValue': np.nan,
                                'dtype': 'float64'}})
