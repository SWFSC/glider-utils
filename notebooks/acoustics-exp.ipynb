# %%
import xarray as xr

# %%
ds = xr.open_dataset("/home/sam_woodman_noaa_gov/amlr03-20231128_grid-delayed-5m_acoustics.nc")
ds
# Out:
# <xarray.Dataset> Size: 43MB
# Dimensions:                (depth: 220, time: 1158)
# Coordinates:
#   * depth                  (depth) float64 2kB 0.5 5.5 ... 1.09e+03 1.096e+03
#     profile                (time) float64 9kB ...
#   * time                   (time) datetime64[ns] 9kB 2023-11-28T20:50:35.8304...
#     longitude              (time) float64 9kB ...
#     latitude               (time) float64 9kB ...
# Data variables: (12/28)
#     profile_time_start     (time) datetime64[ns] 9kB ...
#     profile_time_end       (time) datetime64[ns] 9kB ...
#     profile_index          (depth, time) float64 2MB ...
#     conductivity           (depth, time) float64 2MB ...
#     temperature            (depth, time) float64 2MB ...
#     pressure               (depth, time) float64 2MB ...
#     ...                     ...
#     v                      (time) float64 9kB ...
#     mission_number         int32 4B ...
#     abc_70kHz              (depth, time) float64 2MB ...
#     abc_120kHz             (depth, time) float64 2MB ...
#     num_pings_profile_70   (time) float64 9kB ...
#     num_pings_profile_120  (time) float64 9kB ...
# Attributes: (12/56)
#     Conventions:               CF-1.8
#     Metadata_Conventions:      Unidata Dataset Discovery v1.0, COARDS, CF-1.8
#     acknowledgment:            This work was supported by funding from NOAA.
#     comment:
#     contributor_name:          Christian Reiss, George Watters, Jennifer Wals...
#     contributor_role:          Principal Investigator, Principal Investigator...
#     ...                        ...
#     summary:                   FREEBYRD in the south
#     time_coverage_end:         2024-01-27T12:04:56
#     time_coverage_start:       2023-11-25T11:55:13
#     title:                     amlr03-20231125T1155-delayed
#     transmission_system:       IRIDIUM
#     wmo_id:

# %%
ds.profile_time_start.values
# Out:
# array(['1969-12-31T23:58:56.989631118', '1969-12-31T23:58:56.989735413',
#        '1969-12-31T23:58:56.989052927', ...,
#        '1969-12-31T23:58:56.139160194', '1969-12-31T23:58:56.140046620',
#        '1969-12-31T23:58:56.140190277'],
#       shape=(1158,), dtype='datetime64[ns]')

# %%
ds.abc_70kHz
# Out:
# <xarray.DataArray 'abc_70kHz' (depth: 220, time: 1158)> Size: 2MB
# [254760 values with dtype=float64]
# Coordinates:
#   * depth      (depth) float64 2kB 0.5 5.5 10.5 ... 1.086e+03 1.09e+03 1.096e+03
#     profile    (time) float64 9kB ...
#   * time       (time) datetime64[ns] 9kB 2023-11-28T20:50:35.830488576 ... 20...
#     longitude  (time) float64 9kB ...
#     latitude   (time) float64 9kB ...
# Attributes:
#     units:       m2m-2
#     platform:    platform
#     long_name:   area backscatter coefficeient of 70 kHz
#     instrument:  Nortek mini-echosounder 100 kHz
#     FillValue:   NaN
#     comment:     ABC values in 5m bins of acoustic data exported from Echoview

# %%
ds.abc_70kHz.to_pandas()
# Out:
# time    2023-11-28 20:50:35.830488576  2023-11-28 20:55:25.838644992  \
# depth
# 0.5                               NaN                            NaN
# 5.5                               NaN                            NaN
# 10.5                     9.423667e-11                            NaN
# 15.5                     1.431050e-10                            NaN
# 20.5                     2.020450e-10                            NaN
# ...                               ...                            ...
# 1075.5                            NaN                            NaN
# 1080.5                            NaN                            NaN
# 1085.5                            NaN                            NaN
# 1090.5                            NaN                            NaN
# 1095.5                            NaN                            NaN
#
# time    2023-11-28 21:09:14.868627968  2023-11-28 21:13:56.835348736  \
# depth
# 0.5                               NaN                            NaN
# 5.5                               NaN                            NaN
# 10.5                     2.708000e-11                            NaN
# 15.5                     1.582800e-10                            NaN
# 20.5                     1.579625e-10                            NaN
# ...                               ...                            ...
# 1075.5                            NaN                            NaN
# 1080.5                            NaN                            NaN
# 1085.5                            NaN                            NaN
# 1090.5                            NaN                            NaN
# 1095.5                            NaN                            NaN
#
# time    2023-11-28 21:35:12.752948736  2023-11-28 21:42:55.776595456  \
# depth
# 0.5                               NaN                            NaN
# 5.5                               NaN                            NaN
# 10.5                     2.328320e-10                            NaN
# 15.5                     5.355686e-10                            NaN
# 20.5                     6.453912e-10                            NaN
# ...                               ...                            ...
# 1075.5                            NaN                            NaN
# 1080.5                            NaN                            NaN
# 1085.5                            NaN                            NaN
# 1090.5                            NaN                            NaN
# 1095.5                            NaN                            NaN
#
# time    2023-11-28 21:59:42.021269760  2023-11-28 22:07:44.717221632  \
# depth
# 0.5                               NaN                            NaN
# 5.5                               NaN                            NaN
# 10.5                         0.000025                            NaN
# 15.5                         0.000035                            NaN
# 20.5                         0.000012                            NaN
# ...                               ...                            ...
# 1075.5                            NaN                            NaN
# 1080.5                            NaN                            NaN
# 1085.5                            NaN                            NaN
# 1090.5                            NaN                            NaN
# 1095.5                            NaN                            NaN
#
# time    2023-11-28 22:23:50.759615488  2023-11-28 22:31:38.731008256  ...  \
# depth                                                                 ...
# 0.5                               NaN                            NaN  ...
# 5.5                               NaN                            NaN  ...
# 10.5                     5.356200e-10                            NaN  ...
# 15.5                     1.256180e-09                            NaN  ...
# 20.5                     4.409683e-10                            NaN  ...
# ...                               ...                            ...  ...
# 1075.5                            NaN                            NaN  ...
# 1080.5                            NaN                            NaN  ...
# 1085.5                            NaN                            NaN  ...
# 1090.5                            NaN                            NaN  ...
# 1095.5                            NaN                            NaN  ...
#
# time    2024-01-27 09:22:01.483638528  2024-01-27 09:42:50.481290496  \
# depth
# 0.5                               NaN                            NaN
# 5.5                               NaN                            NaN
# 10.5                     9.778333e-11                            NaN
# 15.5                     1.519703e-09                            NaN
# 20.5                     1.352443e-09                            NaN
# ...                               ...                            ...
# 1075.5                            NaN                            NaN
# 1080.5                            NaN                            NaN
# 1085.5                            NaN                            NaN
# 1090.5                            NaN                            NaN
# 1095.5                            NaN                            NaN
#
# time    2024-01-27 10:16:29.406965504  2024-01-27 10:35:07.401615616  \
# depth
# 0.5                               NaN                            NaN
# 5.5                               NaN                            NaN
# 10.5                     1.276000e-11                            NaN
# 15.5                     3.720500e-11                            NaN
# 20.5                     1.284000e-11                            NaN
# ...                               ...                            ...
# 1075.5                            NaN                            NaN
# 1080.5                            NaN                            NaN
# 1085.5                            NaN                            NaN
# 1090.5                            NaN                            NaN
# 1095.5                            NaN                            NaN
#
# time    2024-01-27 11:03:51.352996352  2024-01-27 11:09:15.403640832  \
# depth
# 0.5                               NaN                            NaN
# 5.5                               NaN                            NaN
# 10.5                     1.332000e-11                            NaN
# 15.5                     2.280400e-10                            NaN
# 20.5                     5.609050e-09                            NaN
# ...                               ...                            ...
# 1075.5                            NaN                            NaN
# 1080.5                            NaN                            NaN
# 1085.5                            NaN                            NaN
# 1090.5                            NaN                            NaN
# 1095.5                            NaN                            NaN
#
# time    2024-01-27 11:26:53.402226176  2024-01-27 11:30:59.381014784  \
# depth
# 0.5                               NaN                            NaN
# 5.5                               NaN                            NaN
# 10.5                     1.315900e-10                            NaN
# 15.5                     1.140000e-12                            NaN
# 20.5                     1.015000e-12                            NaN
# ...                               ...                            ...
# 1075.5                            NaN                            NaN
# 1080.5                            NaN                            NaN
# 1085.5                            NaN                            NaN
# 1090.5                            NaN                            NaN
# 1095.5                            NaN                            NaN
#
# time    2024-01-27 11:45:48.288919040  2024-01-27 11:49:47.367209984
# depth
# 0.5                               NaN                            NaN
# 5.5                               NaN                            NaN
# 10.5                     2.908000e-11                            NaN
# 15.5                     5.122500e-12                            NaN
# 20.5                     3.328075e-10                            NaN
# ...                               ...                            ...
# 1075.5                            NaN                            NaN
# 1080.5                            NaN                            NaN
# 1085.5                            NaN                            NaN
# 1090.5                            NaN                            NaN
# 1095.5                            NaN                            NaN
#
# [220 rows x 1158 columns]
