# %% [markdown]
# # misc-2
#
# A second notebook for miscellaneous code and experiments

# %%
import xarray as xr

# %%
x = xr.open_dataset("C:/Users/sam.woodman/Downloads/amlr08-20220513-delayed-sci.nc")
display(x)

x_pd = x.to_pandas()
x_pd
# Out:
# <xarray.Dataset> Size: 23MB
# Dimensions:                   (time: 113312)
# Coordinates:
#   * time                      (time) datetime64[ns] 906kB 2022-05-13T18:20:19...
# Data variables: (12/24)
#     latitude                  (time) float64 906kB ...
#     longitude                 (time) float64 906kB ...
#     depth                     (time) float64 906kB ...
#     profile_index             (time) float64 906kB ...
#     conductivity              (time) float64 906kB ...
#     temperature               (time) float64 906kB ...
#     ...                        ...
#     waypoint_latitude         (time) float64 906kB ...
#     waypoint_longitude        (time) float64 906kB ...
#     water_velocity_eastward   (time) float64 906kB ...
#     water_velocity_northward  (time) float64 906kB ...
#     distance_over_ground      (time) float64 906kB ...
#     profile_direction         (time) float64 906kB ...
# Attributes: (12/57)
#     Conventions:               CF-1.8
# ...

# %%
# Out:
# '11'

# %%
y = xr.open_dataset("C:/Users/sam.woodman/Downloads/amlr08-20220513-delayed-eng.nc")
display(y)

y_pd = y.to_pandas()
y_pd
# Out:
# <xarray.Dataset> Size: 12MB
# Dimensions:                (time: 59973)
# Coordinates:
#   * time                   (time) datetime64[ns] 480kB 2022-05-13T18:13:42.53...
# Data variables: (12/25)
#     latitude               (time) float64 480kB ...
#     longitude              (time) float64 480kB ...
#     depth                  (time) float64 480kB ...
#     profile_index          (time) float64 480kB ...
#     heading                (time) float64 480kB ...
#     pitch                  (time) float64 480kB ...
#     ...                     ...
#     battpos                (time) float64 480kB ...
#     target_depth           (time) float64 480kB ...
#     altitude               (time) float64 480kB ...
#     total_inflections      (time) float64 480kB ...
#     distance_over_ground   (time) float64 480kB ...
#     profile_direction      (time) float64 480kB ...
# Attributes: (12/57)
#     Conventions:               CF-1.8
# ...
